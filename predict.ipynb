# %%
from tensorflow.keras.models import load_model
import pickle
import pandas as pd
import tensorflow as tf

# %%
with open('label_encoder.pkl', 'rb') as file:
    label = pickle.load(file)

# %%
with open('onehot_encoder.pkl', 'rb') as file:
    onehot = pickle.load(file)

# %%
with open('scaler.pkl', 'rb') as file:
    scaler = pickle.load(file)

# %%
model = load_model('model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
user = {'Pclass':3, 'Sex':'female', 'SibSp':1, 'Parch':1, 'Fare':11, 'Embarked':'Queenstown'}

# %%
user = pd.DataFrame([user])

# %%
user
# Out:
#    Pclass     Sex  SibSp  Parch  Fare    Embarked
# 0       3  female      1      1    11  Queenstown

# %%
user['Sex']=label.transform(user['Sex'])

# %%
user
# Out:
#    Pclass  Sex  SibSp  Parch  Fare    Embarked
# 0       3    0      1      1    11  Queenstown

# %%
embarked = onehot.transform(user[['Embarked']])

# %%
embarked = pd.DataFrame(embarked, columns=onehot.get_feature_names_out())

# %%
embarked
# Out:
#    Embarked_Chebourg  Embarked_Queenstown  Embarked_Southampton
# 0                0.0                  1.0                   0.0

# %%
user =  pd.concat([user.drop(columns = ['Embarked']), embarked], axis = 1)

# %%
user
# Out:
#    Pclass  Sex  ...  Embarked_Queenstown  Embarked_Southampton
# 0       3    0  ...                  1.0                   0.0
#
# [1 rows x 8 columns]

# %%
user[['Pclass',	'SibSp', 'Parch' ,'Fare']] = scaler.transform(user[['Pclass',	'SibSp', 'Parch' ,'Fare']])

# %%
user
# Out:
#      Pclass  Sex  ...  Embarked_Queenstown  Embarked_Southampton
# 0  0.824107    0  ...                  1.0                   0.0
#
# [1 rows x 8 columns]

# %%
y= model.predict(user)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step

# %%
y
# Out:
# array([[0.31130886]], dtype=float32)

# %%
if y>0.5:
    print('The passanger will likely survive the Titanic Journey')
else: 
    print('The passanger wont survive in the Titanic Journey ')
# Out:
# The passanger wont survive in the Titanic Journey
